# %% [markdown]
# Maximise \
# $\hspace{2em}Z = 2x_1 + 3x_2 + 4x_3 + x_4$
#
# Subject to constraints: \
# $\hspace{2em}x_1 + x_2 + 2x_3 + x_4 \leq 20$ \
# $\hspace{2em}2x_1 + x_2 + x_3 + 3x_4 \leq 30$ \
# $\hspace{2em}x_1 + 3x_2 + x_3 + 2x_4 \leq 25$ \
# $\hspace{2em}x_2 + x_3 + x_4 \leq 12$ \
# $\hspace{2em}x_1, x_2, x_3, x_4 \geq 0$

# %% [markdown]
# (Solution is at the bottom)
# ```
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# ```

# %% [markdown]
# Construct canonical tableau form
#
# \begin{bmatrix}
# \begin{array}{c|cccccccc|c}
# 1 & -2 & -3 & -4 & -1 & 0 & 0 & 0 & 0 & 0\\
# \hline
# 0 & 1 & 1 & 2 & 1 & 1 & 0 & 0 & 0 & 20 \\
# 0 & 2 & 1 & 1 & 3 & 0 & 1 & 0 & 0 & 30 \\
# 0 & 1 & 3 & 1 & 2 & 0 & 0 & 1 & 0 & 25 \\
# 0 & 0 & 1 & 1 & 1 & 0 & 0 & 0 & 1 & 12
# \end{array}
# \end{bmatrix}
#
# Entering variable $x_3$, leaving variable $s_1$
# \begin{bmatrix}
# \begin{array}{c|cccccccc|c}
# 1 & 0 & -1 & 0 & 1 & 2 & 0 & 0 & 0 & 40\\
# \hline
# 0 & 1/2 & 1/2 & 1 & 1/2 & 1/2 & 0 & 0 & 0 & 10 \\
# 0 & 3/2 & 1/2 & 0 & 5/2 & -1/2 & 1 & 0 & 0 & 20 \\
# 0 & 1/2 & 5/2 & 0 & 3/2 & -1/2 & 0 & 1 & 0 & 15 \\
# 0 & -1/2 & 1/2 & 0 & 1/2 & -1/2 & 0 & 0 & 1 & 2
# \end{array}
# \end{bmatrix}
#
# Entering variable $x_2$, leaving variable $s_4$
# \begin{bmatrix}
# \begin{array}{c|cccccccc|c}
# 1 & -1 & 0 & 0 & 2 & 1 & 0 & 0 & 2 & 44\\
# \hline
# 0 & 1 & 0 & 1 & 0 & 1 & 0 & 0 & -1 & 8 \\
# 0 & 2 & 0 & 0 & 2 & 0 & 1 & 0 & -1 & 18 \\
# 0 & 3 & 0 & 0 & -1 & 2 & 0 & 1 & -5 & 5 \\
# 0 & -1 & 1 & 0 & 1 & -1 & 0 & 0 & 2 & 4
# \end{array}
# \end{bmatrix}
#
# Entering variable $x_1$, leaving variable $s_3$
# \begin{bmatrix}
# \begin{array}{c|cccccccc|c}
# 1 & 0 & 0 & 0 & 5/3 & 5/3 & 0 & 1/3 & 1/3 & 137/3\\
# \hline
# 0 & 0 & 0 & 1 & 1/3 & 1/3 & 0 & -1/3 & 2/3 & 19/3 \\
# 0 & 0 & 0 & 0 & 8/3 & -4/3 & 1 & -2/3 & 7/3 & 44/3 \\
# 0 & 1 & 0 & 0 & -1/3 & 2/3 & 0 & 1/3 & -5/3 & 5/3 \\
# 0 & 0 & 1 & 0 & 2/3 & -1/3 & 0 & 1/3 & 1/3 & 17/3
# \end{array}
# \end{bmatrix}
#
# Result: (5/3, 17/3, 19/3, 0) with objective value of 137/3
