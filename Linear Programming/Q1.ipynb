# %% [markdown]
# Maximise \
# $\hspace{2em}Z = 3x_1 + 5x_2 + 2x_3$
#
# Subject to constraints: \
# $\hspace{2em}x_1 + x_2 + x_3 \leq 10$ \
# $\hspace{2em}x_1 + 3x_2 + 2x_3 \leq 15$ \
# $\hspace{2em}x_1 + x_2 + 4x_3 \leq 12$ \
# $\hspace{2em}x_1, x_2, x_3 \geq 0$

# %% [markdown]
# (Solution is at the bottom)
# ```
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# ```

# %% [markdown]
# Construct canonical tableau form
#
# \begin{bmatrix}
# \begin{array}{c|cccccc|c}
# 1 & -3 & -5 & -2 & 0 & 0 & 0 & 0 \\
# \hline
# 0 & 1 & 1 & 1 & 1 & 0 & 0 & 10 \\
# 0 & 1 & 3 & 2 & 0 & 1 & 0 & 15 \\
# 0 & 1 & 1 & 4 & 0 & 0 & 1 & 12
# \end{array}
# \end{bmatrix}
#
# Entering variable $x_2$, leaving variable $s_2$
# \begin{bmatrix}
# \begin{array}{c|cccccc|c}
# 1 & -4/3 & 0 & 4/3 & 0 & 5/3 & 0 & 25 \\
# \hline
# 0 & 2/3 & 0 & 1/3 & 1 & -1/3 & 0 & 5 \\
# 0 & 1/3 & 1 & 2/3 & 0 & 1/3 & 0 & 5 \\
# 0 & 2/3 & 0 & 10/3 & 0 & -1/3 & 1 & 7
# \end{array}
# \end{bmatrix}
#
# Entering variable $x_1$, leaving variable $s_1$
# \begin{bmatrix}
# \begin{array}{c|cccccc|c}
# 1 & 0 & 0 & 2 & 2 & 1 & 0 & 35 \\
# \hline
# 0 & 1 & 0 & 1/2 & 3/2 & -1/2 & 0 & 15/2 \\
# 0 & 0 & 1 & 1/2 & 1/2 & 1/2 & 0 & 5/2 \\
# 0 & 0 & 0 & 3 & 0 & 0 & 1 & 9/2
# \end{array}
# \end{bmatrix}
#
# Result: $(7.5, 2.5, 0)$ with objective value of 35
